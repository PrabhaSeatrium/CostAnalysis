# %%
import pandas as pd
import os

folder = r"C:\Users\Weeyong.Tan\OneDrive - Seatrium Ltd (1)\Documents\Post Data Merger Extraction"
filename = "ZMM_POREPORT_All harmonized projects_R1_20260513.xlsx"

# %%
def load_cost_data(folder,file):

    df = pd.read_excel(os.path.join(download_folder,file),sheet_name='Sheet2')

    return df

# %%
df_cost = load_cost_data(folder,filename)
